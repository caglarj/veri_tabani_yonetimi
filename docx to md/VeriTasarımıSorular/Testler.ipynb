# %% [markdown]
# # Veri tabanı Yönetimi
# ## Test Soruları

# %% [markdown]
# ```markdown
# 1. Soru: Veri tabanı nedir?
#
# A) Bir programlama dili
# B) Bilgisayarda saklanan verilerin bir araya getirildiği yapılardır
# C) Bir işletim sistemi türüdür
# D) Bir internet protokolüdür
# E) Bir veri iletim protokolüdür
#
# ```
#
# ```markdown
# 2. Soru: İlişkisel veri modelinde kullanılan temel yapılar nelerdir?
#
# A) Dosya, kayıt, alan
# B) Tablo, satır, sütun
# C) Sınıf, nesne, metot
# D) Anahtar, indeks, kısıtlama
# E) Kodlama, şifreleme, şifre çözme
#
# ```
#
# ```markdown
# 3. Soru: Bir veri tabanı yönetim sistemi (VTYS) nedir?
#
# A) Verilerin saklandığı bir donanım cihazı
# B) Verilerin yönetildiği bir yazılım sistemi
# C) Bir veri aktarım protokolü
# D) Bir bilgisayar ağı türü
# E) Bir internet tarayıcısı eklentisi
# ```
#
# ```markdown
# 4. Soru: Veri tabanı tasarımı yaparken nelere dikkat etmek gerekir?
#
# A) Verilerin olabildiğince az sayıda tabloda tutulması
# B) Verilerin mümkün olduğunca çok sayıda tabloda tutulması
# C) Verilerin doğru bir şekilde normalizasyon işlemine tabi tutulması
# D) Verilerin hiçbir şekilde normalizasyon işlemine tabi tutulmaması
# E) Verilerin rastgele bir şekilde dağıtılması
# ```
#
# ```markdown
# 5. Soru: Veri tabanı güvenliği için hangi önlemler alınabilir?
#
# A) Veri tabanı erişim izinlerinin doğru bir şekilde ayarlanması
# B) Veri tabanı yedeklerinin düzenli olarak alınması
# C) Veri tabanı kullanıcılarının kimlik doğrulamasının yapılması
# D) Veri tabanı sisteminin güncel tutulması
# E) Tüm verilerin açık bir şekilde saklanması
# ```
#
# ```markdown
# 6. Soru: Veri tabanı nedir ve bir veri tabanının temel bileşenleri nelerdir?
#
# A) Bir veri tabanı yönetim sistemi yazılımı olarak veri tabanlarının tanımı
# B) Verilerin birbirleriyle ilişkisini tanımlayan bir model
# C) Verilerin saklanabileceği bir arayüz
# D) Verilerin tutulduğu fiziksel ve mantıksal yapılar
# E) Tüm verilerin bellekte saklandığı bir arabellek
# ```
#
# ```markdown
# 7. Soru: Veri tabanı tasarımı yaparken, normalizasyonun amacı nedir ve hangi normal formlar bulunmaktadır?
#
# A) Verilerin depolanması için en iyi fiziksel düzeni sağlamak
# B) Verilerin kullanımını hızlandırmak için gereksiz verileri kaldırmak
# C) Verilerin gereksiz tekrarını önlemek için ilişkisel yapılarda verileri bölmek
# D) Verilerin yedeklenmesi ve geri yüklenmesi için uygun hale getirmek
# E) Verilerin kullanımını azaltmak için veri tabanlarının bölünmesi
# ```
#
#
# ```markdown
# 8. Soru: İlişkisel veri tabanı yönetim sistemlerinde kullanılan JOIN işlemi nedir ve hangi türleri bulunmaktadır?
#
# A) İki ya da daha fazla tablodaki verileri birleştirmek için kullanılan işlem ve INNER, LEFT, RIGHT ve FULL olmak üzere dört türü bulunur
# B) Veri tabanı yönetim sistemi yazılımı içerisinde kullanılan bir algoritma
# C) Veri tabanları arasında veri transferi yapmak için kullanılan bir protokol
# D) Veri tabanı yöneticisinin kullanıcıları için verileri düzenleme ve filtreleme seçenekleri
# E) Verilerin saklanması için gereken fiziksel yapıların tanımlanmasında kullanılan bir terim
# ```
#
# ```markdown
# 9. Soru: Veri tabanı performansını artırmak için alınabilecek önlemler nelerdir?
#
# A) Veri tabanı boyutlarını azaltmak için gereksiz verileri kaldırmak
# B) Veri tabanı üzerinde daha sıkı denetimler uygulamak için erişim izinlerini düzenlemek
# C) Veri tabanı sorgularını optimize etmek için indexlemeyi kullanmak
# D) Veri tabanı sunucusunun donanımını güncellemek
# E) Veri tabanı yedeklerinin daha sık alınması
# ```
#
# ```markdown
# 10. Tablolarda birincil anahtar (primary key) kullanımının önemi nedir?
#
# A) Verilerin tutarlılığı ve bütünlüğünü sağlar.
# B) Verilerin tekilleştirilmesini sağlar.
# C) Veri tabanındaki verilerin hızlı bir şekilde bulunmasını sağlar.
# D) Verilerin yedeklenmesini sağlar.
# E) Verilerin güncellenmesini sağlar.
# ```
